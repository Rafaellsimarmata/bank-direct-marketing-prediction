# %%
import os
from absl import logging
from tfx.orchestration import pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner
from modules.components import init_components
from modules.pipeline import init_pipeline

# %%
PIPELANE_NAME = "marketing-classification-pipeline"

# Pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/transform.py"
TUNER_MODULE_FILE = "modules/tuner.py"
TRAINER_MODULE_FILE = "modules/trainer.py"

# Pipeline outputs
OUTPUT_BASE = "outputs"

SERVING_MODEL_DIR = os.path.join(OUTPUT_BASE, "serving_model")
PIPELINE_ROOT = os.path.join(OUTPUT_BASE, PIPELANE_NAME)
METADATA_PATH = os.path.join(PIPELINE_ROOT, "metadata.sqlite")

# %%
components = init_components(
        DATA_ROOT,
        training_module=TRAINER_MODULE_FILE,
        transform_module=TRANSFORM_MODULE_FILE,
        training_steps=1000,
        tuner_module=TUNER_MODULE_FILE,
        eval_steps=1000,
        serving_model_dir=SERVING_MODEL_DIR,
    )
    
pipeline = init_pipeline(pipeline_root=PIPELINE_ROOT, pipeline_name=PIPELANE_NAME, metadata_path=METADATA_PATH, components=components)
BeamDagRunner().run(pipeline=pipeline)
# Out:
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ContextQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[<class 'str'>, Union[<class 'NoneType'>, <class 'tfx.components.transform.executor._Dataset'>]], Union[<class 'NoneType'>, Dict[<class 'str'>, Dict[<class 'str'>, <class 'apache_beam.pvalue.PCollection'>]]], <class 'int'>] instead.
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_8/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_9/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_8/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_9/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[<class 'str'>, Union[<class 'NoneType'>, <class 'tfx.components.transform.executor._Dataset'>]], Union[<class 'NoneType'>, Dict[<class 'str'>, Dict[<class 'str'>, <class 'apache_beam.pvalue.PCollection'>]]], <class 'int'>] instead.
# WARNING:root:This input type hint will be ignored and not used for type-checking purposes. Typically, input type hints for a PTransform are single (or nested) types wrapped by a PCollection, or PBegin. Got: Dict[<class 'tensorflow_transform.beam.analyzer_cache.DatasetKey'>, <class 'tensorflow_transform.beam.analyzer_cache.DatasetCache'>] instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: List[<class 'apache_beam.pvalue.PDone'>] instead.
# WARNING:root:This input type hint will be ignored and not used for type-checking purposes. Typically, input type hints for a PTransform are single (or nested) types wrapped by a PCollection, or PBegin. Got: Dict[<class 'tensorflow_transform.beam.analyzer_cache.DatasetKey'>, <class 'tensorflow_transform.beam.analyzer_cache.DatasetCache'>] instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: List[<class 'apache_beam.pvalue.PDone'>] instead.
# INFO:tensorflow:Assets written to: outputs\marketing-classification-pipeline\Transform\transform_graph\56\.temp_path\tftransform_tmp\4a32b868c8c9495ebc2b91918939e984\assets
# INFO:tensorflow:Assets written to: outputs\marketing-classification-pipeline\Transform\transform_graph\56\.temp_path\tftransform_tmp\4a32b868c8c9495ebc2b91918939e984\assets
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: outputs\marketing-classification-pipeline\Transform\transform_graph\56\.temp_path\tftransform_tmp\fc71ec8a5faf46779c298c3894cea3a4\assets
# INFO:tensorflow:Assets written to: outputs\marketing-classification-pipeline\Transform\transform_graph\56\.temp_path\tftransform_tmp\fc71ec8a5faf46779c298c3894cea3a4\assets
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# ERROR:absl:Execution 56 failed.
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py in _handle_batch(self, batch)
#     350       else:
# --> 351         result = self._graph_state.callable_get_outputs(feed_dict)
#     352         assert len(self._graph_state.outputs_tensor_keys) == len(result)
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\saved\saved_transform_io_v2.py in apply_transform_model(self, logical_input_map)
#     378     elif self._is_finalized:
# --> 379       return self._apply_v2_transform_model_finalized(logical_input_map)
#     380     else:
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\saved\saved_transform_io_v2.py in _apply_v2_transform_model_finalized(self, logical_input_map)
#     302     modified_inputs = self._format_input_map_as_tensors(logical_input_map)
# --> 303     return self._wrapped_function_finalized(modified_inputs)
#     304
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    1601     """
# -> 1602     return self._call_impl(args, kwargs)
#    1603
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1610         try:
# -> 1611           return self._call_with_structured_signature(args, kwargs,
#    1612                                                       cancellation_manager)
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow\python\eager\function.py in _call_with_structured_signature(self, args, kwargs, cancellation_manager)
#    1691     self._structured_signature_check_arg_types(args, kwargs)
# -> 1692     return self._call_flat(
#    1693         filtered_flat_args,
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#
# UnimplementedError: Graph execution error:
#
# Detected at node 'Cast_2' defined at (most recent call last):
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 2975, in run_cell
#       result = self._run_cell(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3030, in _run_cell
#       return runner(coro)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3257, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3473, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\ACER\AppData\Local\Temp\ipykernel_9944\3424937798.py", line 12, in <cell line: 12>
#       BeamDagRunner().run(pipeline=pipeline)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\tfx_runner.py", line 124, in run
#       return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 297, in run_with_ir
#       logging.info('Node %s is scheduled.', node_id)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 600, in __exit__
#       self.result = self.run()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 577, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\direct\direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 202, in run_pipeline
#       self._latest_run_result = self.run_via_runner_api(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 224, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 455, in run_stages
#       bundle_results = self._execute_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 783, in _execute_bundle
#       self._run_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1012, in _run_bundle
#       result, splits = bundle_manager.process_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1348, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py", line 379, in push
#       response = self.worker.do_instruction(request)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 624, in do_instruction
#       return getattr(self, request_type)(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 662, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 1062, in process_bundle
#       input_op_by_transform_id[element.transform_id].process_encoded(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 232, in process_encoded
#       self.output(decoded_value)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 90, in process
#       self._run_node()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 99, in _run_node
#       launcher.Launcher(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\launcher.py", line 571, in launch
#       executor_output = self._run_executor(execution_info)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\launcher.py", line 446, in _run_executor
#       executor_output = self._executor_operator.run_executor(execution_info)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\beam_executor_operator.py", line 98, in run_executor
#       return python_executor_operator.run_with_executor(execution_info, executor)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py", line 58, in run_with_executor
#       result = executor.Do(execution_info.input_dict, output_dict,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 586, in Do
#       TransformProcessor().Transform(label_inputs, label_outputs, status_file)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 1138, in Transform
#       self._RunBeamImpl(analyze_data_list, transform_data_list, preprocessing_fn,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 1522, in _RunBeamImpl
#       (dataset.transformed
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 600, in __exit__
#       self.result = self.run()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 577, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\direct\direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 202, in run_pipeline
#       self._latest_run_result = self.run_via_runner_api(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 224, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 455, in run_stages
#       bundle_results = self._execute_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 783, in _execute_bundle
#       self._run_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1012, in _run_bundle
#       result, splits = bundle_manager.process_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1348, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py", line 379, in push
#       response = self.worker.do_instruction(request)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 624, in do_instruction
#       return getattr(self, request_type)(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 662, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 1062, in process_bundle
#       input_op_by_transform_id[element.transform_id].process_encoded(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 232, in process_encoded
#       self.output(decoded_value)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 404, in process
#       self._graph_state = self._shared_graph_state_handle.acquire(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 305, in acquire
#       return _shared_map.acquire(self._key, constructor_fn, tag)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 246, in acquire
#       result = control_block.acquire(constructor_fn, tag)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 139, in acquire
#       result = constructor_fn()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 405, in <lambda>
#       lambda: self._make_graph_state(saved_model_dir))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 371, in _make_graph_state
#       result = self._GraphStateV2(saved_model_dir,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 221, in __init__
#       saved_model_loader = saved_transform_io_v2.SavedModelLoader(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\saved\saved_transform_io_v2.py", line 133, in __init__
#       imported = tf.compat.v2.saved_model.load(saved_model_dir)
# Node: 'Cast_2'
# Cast string to int64 is not supported
# 	 [[{{node Cast_2}}]] [Op:__inference_wrapped_finalized_105162]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common._OutputHandler.handle_process_outputs()
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py in process(self, batch, saved_model_dir)
#     410
# --> 411     yield self._handle_batch(batch)
#     412
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py in _handle_batch(self, batch)
#     353     except Exception as e:
# --> 354       raise ValueError(
#     355           """An error occured while trying to apply the transformation: "{}".
#
# ValueError: An error occured while trying to apply the transformation: "Graph execution error:
#
# Detected at node 'Cast_2' defined at (most recent call last):
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 2975, in run_cell
#       result = self._run_cell(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3030, in _run_cell
#       return runner(coro)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3257, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3473, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\ACER\AppData\Local\Temp\ipykernel_9944\3424937798.py", line 12, in <cell line: 12>
#       BeamDagRunner().run(pipeline=pipeline)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\tfx_runner.py", line 124, in run
#       return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 297, in run_with_ir
#       logging.info('Node %s is scheduled.', node_id)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 600, in __exit__
#       self.result = self.run()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 577, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\direct\direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 202, in run_pipeline
#       self._latest_run_result = self.run_via_runner_api(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 224, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 455, in run_stages
#       bundle_results = self._execute_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 783, in _execute_bundle
#       self._run_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1012, in _run_bundle
#       result, splits = bundle_manager.process_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1348, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py", line 379, in push
#       response = self.worker.do_instruction(request)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 624, in do_instruction
#       return getattr(self, request_type)(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 662, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 1062, in process_bundle
#       input_op_by_transform_id[element.transform_id].process_encoded(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 232, in process_encoded
#       self.output(decoded_value)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 90, in process
#       self._run_node()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 99, in _run_node
#       launcher.Launcher(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\launcher.py", line 571, in launch
#       executor_output = self._run_executor(execution_info)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\launcher.py", line 446, in _run_executor
#       executor_output = self._executor_operator.run_executor(execution_info)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\beam_executor_operator.py", line 98, in run_executor
#       return python_executor_operator.run_with_executor(execution_info, executor)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py", line 58, in run_with_executor
#       result = executor.Do(execution_info.input_dict, output_dict,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 586, in Do
#       TransformProcessor().Transform(label_inputs, label_outputs, status_file)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 1138, in Transform
#       self._RunBeamImpl(analyze_data_list, transform_data_list, preprocessing_fn,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 1522, in _RunBeamImpl
#       (dataset.transformed
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 600, in __exit__
#       self.result = self.run()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 577, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\direct\direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 202, in run_pipeline
#       self._latest_run_result = self.run_via_runner_api(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 224, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 455, in run_stages
#       bundle_results = self._execute_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 783, in _execute_bundle
#       self._run_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1012, in _run_bundle
#       result, splits = bundle_manager.process_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1348, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py", line 379, in push
#       response = self.worker.do_instruction(request)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 624, in do_instruction
#       return getattr(self, request_type)(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 662, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 1062, in process_bundle
#       input_op_by_transform_id[element.transform_id].process_encoded(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 232, in process_encoded
#       self.output(decoded_value)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 404, in process
#       self._graph_state = self._shared_graph_state_handle.acquire(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 305, in acquire
#       return _shared_map.acquire(self._key, constructor_fn, tag)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 246, in acquire
#       result = control_block.acquire(constructor_fn, tag)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 139, in acquire
#       result = constructor_fn()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 405, in <lambda>
#       lambda: self._make_graph_state(saved_model_dir))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 371, in _make_graph_state
#       result = self._GraphStateV2(saved_model_dir,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 221, in __init__
#       saved_model_loader = saved_transform_io_v2.SavedModelLoader(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\saved\saved_transform_io_v2.py", line 133, in __init__
#       imported = tf.compat.v2.saved_model.load(saved_model_dir)
# Node: 'Cast_2'
# Cast string to int64 is not supported
# 	 [[{{node Cast_2}}]] [Op:__inference_wrapped_finalized_105162]".
#           Batch instances: pyarrow.RecordBatch
# age: large_list<item: int64>
#   child 0, item: int64
# campaign: large_list<item: int64>
#   child 0, item: int64
# cons.conf.idx: large_list<item: float>
#   child 0, item: float
# cons.price.idx: large_list<item: float>
#   child 0, item: float
# contact: large_list<item: large_binary>
#   child 0, item: large_binary
# day_of_week: large_list<item: large_binary>
#   child 0, item: large_binary
# default: large_list<item: large_binary>
#   child 0, item: large_binary
# education: large_list<item: large_binary>
#   child 0, item: large_binary
# emp.var.rate: large_list<item: float>
#   child 0, item: float
# euribor3m: large_list<item: float>
#   child 0, item: float
# housing: large_list<item: large_binary>
#   child 0, item: large_binary
# job: large_list<item: large_binary>
#   child 0, item: large_binary
# loan: large_list<item: large_binary>
#   child 0, item: large_binary
# marital: large_list<item: large_binary>
#   child 0, item: large_binary
# month: large_list<item: large_binary>
#   child 0, item: large_binary
# nr.employed: large_list<item: float>
#   child 0, item: float
# pdays: large_list<item: int64>
#   child 0, item: int64
# poutcome: large_list<item: large_binary>
#   child 0, item: large_binary
# previous: large_list<item: int64>
#   child 0, item: int64
# y: large_list<item: large_binary>
#   child 0, item: large_binary,
#           Fetching the values for the following Tensor keys: {'previous_xf', 'contact_xf', 'housing_xf', 'pdays', 'month_xf', 'day_of_week_xf', 'default_xf', 'age_xf', 'nr.employed_xf', 'campaign_xf', 'y', 'job_xf', 'marital_xf', 'education_xf', 'loan_xf', 'euribor3m_xf', 'cons.price.idx_xf', 'y_xf', 'emp.var.rate_xf', 'poutcome_xf', 'cons.conf.idx_xf'}.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9944\3424937798.py in <cell line: 12>()
#      10
#      11 pipeline = init_pipeline(pipeline_root=PIPELINE_ROOT, pipeline_name=PIPELANE_NAME, metadata_path=METADATA_PATH, components=components)
# ---> 12 BeamDagRunner().run(pipeline=pipeline)
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\tfx_runner.py in run(self, pipeline, run_options, **kwargs)
#     122     else:
#     123       run_options_pb = None
# --> 124     return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in run_with_ir(self, pipeline, run_options)
#     295                       pipeline=pipeline),
#     296                   *[beam.pvalue.AsIter(s) for s in signals_to_wait]))
# --> 297           logging.info('Node %s is scheduled.', node_id)
#
# c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     598     try:
# ...
#       return _run_code(code, main_globals, None,
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 2975, in run_cell
#       result = self._run_cell(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3030, in _run_cell
#       return runner(coro)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3257, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3473, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\ACER\AppData\Local\Temp\ipykernel_9944\3424937798.py", line 12, in <cell line: 12>
#       BeamDagRunner().run(pipeline=pipeline)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\tfx_runner.py", line 124, in run
#       return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 297, in run_with_ir
#       logging.info('Node %s is scheduled.', node_id)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 600, in __exit__
#       self.result = self.run()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 577, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\direct\direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 202, in run_pipeline
#       self._latest_run_result = self.run_via_runner_api(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 224, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 455, in run_stages
#       bundle_results = self._execute_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 783, in _execute_bundle
#       self._run_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1012, in _run_bundle
#       result, splits = bundle_manager.process_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1348, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py", line 379, in push
#       response = self.worker.do_instruction(request)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 624, in do_instruction
#       return getattr(self, request_type)(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 662, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 1062, in process_bundle
#       input_op_by_transform_id[element.transform_id].process_encoded(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 232, in process_encoded
#       self.output(decoded_value)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 90, in process
#       self._run_node()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py", line 99, in _run_node
#       launcher.Launcher(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\launcher.py", line 571, in launch
#       executor_output = self._run_executor(execution_info)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\launcher.py", line 446, in _run_executor
#       executor_output = self._executor_operator.run_executor(execution_info)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\beam_executor_operator.py", line 98, in run_executor
#       return python_executor_operator.run_with_executor(execution_info, executor)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py", line 58, in run_with_executor
#       result = executor.Do(execution_info.input_dict, output_dict,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 586, in Do
#       TransformProcessor().Transform(label_inputs, label_outputs, status_file)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 1138, in Transform
#       self._RunBeamImpl(analyze_data_list, transform_data_list, preprocessing_fn,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tfx\components\transform\executor.py", line 1522, in _RunBeamImpl
#       (dataset.transformed
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 600, in __exit__
#       self.result = self.run()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\pipeline.py", line 577, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\direct\direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 202, in run_pipeline
#       self._latest_run_result = self.run_via_runner_api(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 224, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 455, in run_stages
#       bundle_results = self._execute_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 783, in _execute_bundle
#       self._run_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1012, in _run_bundle
#       result, splits = bundle_manager.process_bundle(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py", line 1348, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py", line 379, in push
#       response = self.worker.do_instruction(request)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 624, in do_instruction
#       return getattr(self, request_type)(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\sdk_worker.py", line 662, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 1062, in process_bundle
#       input_op_by_transform_id[element.transform_id].process_encoded(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\runners\worker\bundle_processor.py", line 232, in process_encoded
#       self.output(decoded_value)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 404, in process
#       self._graph_state = self._shared_graph_state_handle.acquire(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 305, in acquire
#       return _shared_map.acquire(self._key, constructor_fn, tag)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 246, in acquire
#       result = control_block.acquire(constructor_fn, tag)
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\apache_beam\utils\shared.py", line 139, in acquire
#       result = constructor_fn()
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 405, in <lambda>
#       lambda: self._make_graph_state(saved_model_dir))
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 371, in _make_graph_state
#       result = self._GraphStateV2(saved_model_dir,
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\beam\impl.py", line 221, in __init__
#       saved_model_loader = saved_transform_io_v2.SavedModelLoader(
#     File "c:\Users\ACER\Documents\USU\Semester6\DBS_Journey\mlops_2\.venv\lib\site-packages\tensorflow_transform\saved\saved_transform_io_v2.py", line 133, in __init__
#       imported = tf.compat.v2.saved_model.load(saved_model_dir)
# Node: 'Cast_2'
# Cast string to int64 is not supported
# 	 [[{{node Cast_2}}]] [Op:__inference_wrapped_finalized_105162]".
#           Batch instances: pyarrow.RecordBatch
# age: large_list<item: int64>
#   child 0, item: int64
# campaign: large_list<item: int64>
#   child 0, item: int64
# cons.conf.idx: large_list<item: float>
#   child 0, item: float
# cons.price.idx: large_list<item: float>
#   child 0, item: float
# contact: large_list<item: large_binary>
#   child 0, item: large_binary
# day_of_week: large_list<item: large_binary>
#   child 0, item: large_binary
# default: large_list<item: large_binary>
#   child 0, item: large_binary
# education: large_list<item: large_binary>
#   child 0, item: large_binary
# emp.var.rate: large_list<item: float>
#   child 0, item: float
# euribor3m: large_list<item: float>
#   child 0, item: float
# housing: large_list<item: large_binary>
#   child 0, item: large_binary
# job: large_list<item: large_binary>
#   child 0, item: large_binary
# loan: large_list<item: large_binary>
#   child 0, item: large_binary
# marital: large_list<item: large_binary>
#   child 0, item: large_binary
# month: large_list<item: large_binary>
#   child 0, item: large_binary
# nr.employed: large_list<item: float>
#   child 0, item: float
# pdays: large_list<item: int64>
#   child 0, item: int64
# poutcome: large_list<item: large_binary>
#   child 0, item: large_binary
# previous: large_list<item: int64>
#   child 0, item: int64
# y: large_list<item: large_binary>
#   child 0, item: large_binary,
#           Fetching the values for the following Tensor keys: {'previous_xf', 'contact_xf', 'housing_xf', 'pdays', 'month_xf', 'day_of_week_xf', 'default_xf', 'age_xf', 'nr.employed_xf', 'campaign_xf', 'y', 'job_xf', 'marital_xf', 'education_xf', 'loan_xf', 'euribor3m_xf', 'cons.price.idx_xf', 'y_xf', 'emp.var.rate_xf', 'poutcome_xf', 'cons.conf.idx_xf'}. [while running 'Transform[TransformIndex1]/Transform']
